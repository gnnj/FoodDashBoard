# %%
# Import Dependencies
import pandas as pd

# %%
# Path to the CSV
file = "../RawData/vegetarian_restaurants_US_datafiniti.csv"

# Read the CSV into Pandas
df = pd.read_csv(file)
df.head
# Out:
# <bound method NDFrame.head of                          address  \
# 0          2871 Gulf To Bay Blvd
# 1                  605 W Main St
# 2                3803 9th St S W
# 3                   30 S Main St
# 4                 55 Crescent Dr
# 5              2243 Richmond Ave
# 6               8007 State Rt 31
# 7                415 Thompson Ln
# 8                217 W Beloit St
# 9               309 N Lamar Blvd
# 10             1819 Lake Cook Rd
# 11            6286 N College Ave
# 12                145 Charles St
# 13                 113 Monroe St
# 14                 302 S 38th St
# 15               7830 Highway 92
# 16                  26 5th Ave N
# 17          249 N Rocky River Dr
# 18                240 College St
# 19                 1912 W 5600 S
# 20              242 S Beverly Dr
# 21                  9816 4th Ave
# 22                   Po Box 6514
# 23             106 Commercial St
# 24                 222 E Main St
# 25             14810 Detroit Ave
# ...

# %%
df.columns
# Out:
# Index(['address', 'categories', 'city', 'claimed', 'country', 'cuisines',
#        'dateOpened', 'dateUpdated', 'descriptions', 'facebookPageURL',
#        'features', 'hours', 'images', 'isClosed', 'key', 'lat', 'languages',
#        'long', 'menus', 'menuURL', 'name', 'paymentTypes', 'phones',
#        'postalCode', 'priceRange', 'province', 'sic', 'twitter', 'websites'],
#       dtype='object')

# %%
new_df = df.loc[:, ["name", "address", "city", "providence", "postalCode", "phones", "cuisines", "descriptions", "features", "lat", "long"]]
new_df
# Out:
#                                                    name  \
# 0                     Village Inn Restaurant and Bakery
# 1                                        Atlantic No. 5
# 2                                         Famous Dave's
# 3                                              The Feve
# 4                                               Quiznos
# 5                                           Hobbit Cafe
# 6                                         Familia Pizza
# 7                            Lalibela Ethiopian Cuisine
# 8                                  Villa Pizza (closed)
# 9                                          The Pita Pit
# 10                            P.f. Chang's China Bistro
# 11                                        Marco's Pizza
# 12                                               King I
# 13                                            Pizza Pit
# 14                                            Mcforters
# 15                             Sonny's Real Pit Bar-b-q
# ...
