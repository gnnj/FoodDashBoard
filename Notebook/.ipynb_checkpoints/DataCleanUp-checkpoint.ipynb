# %%
# Import Dependencies
import pandas as pd
import json
import requests
import numpy as np

# %%
# Path to the CSV
file = "../RawData/vegetarian_restaurants_US_datafiniti.csv"

# Read the CSV into Pandas
df = pd.read_csv(file)
df.head
# Out:
# <bound method NDFrame.head of                          address  \
# 0          2871 Gulf To Bay Blvd
# 1                  605 W Main St
# 2                3803 9th St S W
# 3                   30 S Main St
# 4                 55 Crescent Dr
# 5              2243 Richmond Ave
# 6               8007 State Rt 31
# 7                415 Thompson Ln
# 8                217 W Beloit St
# 9               309 N Lamar Blvd
# 10             1819 Lake Cook Rd
# 11            6286 N College Ave
# 12                145 Charles St
# 13                 113 Monroe St
# 14                 302 S 38th St
# 15               7830 Highway 92
# 16                  26 5th Ave N
# 17          249 N Rocky River Dr
# 18                240 College St
# 19                 1912 W 5600 S
# 20              242 S Beverly Dr
# 21                  9816 4th Ave
# 22                   Po Box 6514
# 23             106 Commercial St
# 24                 222 E Main St
# 25             14810 Detroit Ave
# ...

# %%
df.columns
# Out:
# Index(['address', 'categories', 'city', 'claimed', 'country', 'cuisines',
#        'dateOpened', 'dateUpdated', 'descriptions', 'facebookPageURL',
#        'features', 'hours', 'images', 'isClosed', 'key', 'lat', 'languages',
#        'long', 'menus', 'menuURL', 'name', 'paymentTypes', 'phones',
#        'postalCode', 'priceRange', 'province', 'sic', 'twitter', 'websites'],
#       dtype='object')

# %%
new_df = df.loc[:, ["name", "address", "city", "province", "postalCode", "phones", "cuisines", "descriptions", "features", "lat", "long"]]
new_df
# Out:
#                                                    name  \
# 0                     Village Inn Restaurant and Bakery
# 1                                        Atlantic No. 5
# 2                                         Famous Dave's
# 3                                              The Feve
# 4                                               Quiznos
# 5                                           Hobbit Cafe
# 6                                         Familia Pizza
# 7                            Lalibela Ethiopian Cuisine
# 8                                  Villa Pizza (closed)
# 9                                          The Pita Pit
# 10                            P.f. Chang's China Bistro
# 11                                        Marco's Pizza
# 12                                               King I
# 13                                            Pizza Pit
# 14                                            Mcforters
# 15                             Sonny's Real Pit Bar-b-q
# ...

# %%
clean_df = new_df.dropna(subset=['lat'])
clean_df
# Out:
#                                                    name  \
# 0                     Village Inn Restaurant and Bakery
# 1                                        Atlantic No. 5
# 2                                         Famous Dave's
# 3                                              The Feve
# 4                                               Quiznos
# 5                                           Hobbit Cafe
# 7                            Lalibela Ethiopian Cuisine
# 8                                  Villa Pizza (closed)
# 9                                          The Pita Pit
# 10                            P.f. Chang's China Bistro
# 11                                        Marco's Pizza
# 12                                               King I
# 13                                            Pizza Pit
# 14                                            Mcforters
# 16                                   Milio's Sandwiches
# 17                 Oven Fresh Pizza - Southwest - Berea
# ...

# %%
# Count before drop
len(new_df)
# Out:
# 18155

# %%
# Count after drop
len(clean_df)
# Out:
# 13704

# %%
# Create lists for Yelp API Data
name = []
restaurant_name = []
lat = []
long = []
address = []
city = []
state = []
zip_code = []
phone = []
cuisine_type = []
rating = []
price = []
latitude = []
longitude = []

# Add restaurant names, latitude, and longitude to a list to a list
name = clean_df["name"].tolist()
lat = clean_df["lat"].tolist()
long = clean_df["long"].tolist()

name_list = pd.DataFrame(np.column_stack([name, lat, long]), 
                               columns=['resturant_name', 'latitude', 'longitude'])
name_list.head()
# Out:
#                       resturant_name            latitude            longitude
# 0  Village Inn Restaurant and Bakery  27.971165000000003           -82.696938
# 1                     Atlantic No. 5         38.25702035         -85.76001328
# 2                      Famous Dave's           47.154828          -122.303992
# 3                           The Feve         41.29082277         -82.21764028
# 4                            Quiznos         37.94566339  -122.06199690000001

# %%
for x in range(0, len(name_list)):
    term = name_list.iloc[x]['resturant_name']
    latitude = name_list.iloc[x]['latitude']
    longitude = name_list.iloc[x]['latitude']
    querystring = {"term":term,"latitude":latitude,"longitude":longitude,"limit":"1"}
# Out:
# {'term': 'Village Inn Restaurant and Bakery', 'latitude': '27.971165000000003', 'longitude': '27.971165000000003', 'limit': '1'}
# {'term': 'Atlantic No. 5', 'latitude': '38.25702035', 'longitude': '38.25702035', 'limit': '1'}
# {'term': "Famous Dave's", 'latitude': '47.154828', 'longitude': '47.154828', 'limit': '1'}
# {'term': 'The Feve', 'latitude': '41.29082277', 'longitude': '41.29082277', 'limit': '1'}
# {'term': 'Quiznos', 'latitude': '37.94566339', 'longitude': '37.94566339', 'limit': '1'}
# {'term': 'Hobbit Cafe', 'latitude': '29.7336', 'longitude': '29.7336', 'limit': '1'}
# {'term': 'Lalibela Ethiopian Cuisine', 'latitude': '36.11988', 'longitude': '36.11988', 'limit': '1'}
# {'term': 'Villa Pizza (closed)', 'latitude': '42.635024', 'longitude': '42.635024', 'limit': '1'}
# {'term': 'The Pita Pit', 'latitude': '34.36802', 'longitude': '34.36802', 'limit': '1'}
# ...

# %%
url = "https://api.yelp.com/v3/businesses/search"

headers = {
    'authorization': "Bearer Vq7NhNf0npR8Ki7ka12hfLgHiw-GQ7e2dI0AziNivXvglpD3YH4FAfkgNRlz8sX5bLJJXIZXWRt2j0hoBEzWCWbl6Fnl_aNmRtqEr81xjkoeZjpzrbAXqEYC3z-tWnYx",
    'cache-control': "no-cache",
    'postman-token': "20a751e8-52bb-50de-89b0-fc309cfbadf8"
    }

record_count = 1
group_number = 1

for x in range(0, len(name_list)):
    try:
        term = name_list.iloc[x]['resturant_name']
        latitude = name_list.iloc[x]['latitude']
        longitude = name_list.iloc[x]['latitude']
        querystring = {"term":term,"latitude":latitude,"longitude":longitude,"limit":"1"}
        response = requests.request("GET", url, headers=headers, params=querystring)
        data = response.json()
        # Store response as variables
        r1 = data['businesses'][0]['name']
        r2 = data['businesses'][0]['location']['address1']
        r3 = data['businesses'][0]['location']['city']
        r4 = data['businesses'][0]['location']['state']
        r5 = data['businesses'][0]['location']['zip_code']
        r6 = data['businesses'][0]['phone']
        r7 = data['businesses'][0]['categories'][0]['title']
        r8 = data['businesses'][0]['rating']
        r9 = data['businesses'][0]['price']
        r10 = data['businesses'][0]['coordinates']['latitude']
        r11 = data['businesses'][0]['coordinates']['longitude']
        # Append to lists
        restaurant_name.append(r1)
        address.append(r2)
        city.append(r3)
        state.append(r4)
        zip_code.append(r5)
        phone.append(r6)
        cuisine_type.append(r7)
        rating.append(r8)
        price.append(r9)
        latitude.append(r10)
        longitude.append(r11)
    except:
        print("No info from API")
        continue
    
    # Pause every 50 API Calls
    if record_count < 50:
        record_count = record_count + 1
    elif record_count == 50:
        time.sleep(15)
        record_count = 1
        group_number = group_number + 1
# Out:
# No info from API
# No info from API
# No info from API

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search"

querystring = {"term":"delis","latitude":"37.786882","longitude":"-122.399972","limit":"1"}

headers = {
    'authorization': "Bearer Vq7NhNf0npR8Ki7ka12hfLgHiw-GQ7e2dI0AziNivXvglpD3YH4FAfkgNRlz8sX5bLJJXIZXWRt2j0hoBEzWCWbl6Fnl_aNmRtqEr81xjkoeZjpzrbAXqEYC3z-tWnYx",
    'cache-control': "no-cache",
    'postman-token': "20a751e8-52bb-50de-89b0-fc309cfbadf8"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

data = response.json()

r1 = data['businesses'][0]['name']
r2 = data['businesses'][0]['location']['address1']
r3 = data['businesses'][0]['location']['city']
r4 = data['businesses'][0]['location']['state']
r5 = data['businesses'][0]['location']['zip_code']
r6 = data['businesses'][0]['phone']
r7 = data['businesses'][0]['categories'][0]['title']
r8 = data['businesses'][0]['rating']
r9 = data['businesses'][0]['price']
r10 = data['businesses'][0]['coordinates']['latitude']
r11 = data['businesses'][0]['coordinates']['longitude']

restaurant_name.append(r1)
address.append(r2)
city.append(r3)
state.append(r4)
zip_code.append(r5)
phone.append(r6)
cuisine_type.append(r7)
rating.append(r8)
price.append(r9)
latitude.append(r10)
longitude.append(r11)


print(restaurant_name)
print(address)
print(city)
print(state)
print(zip_code)
print(phone)
print(cuisine_type)
print(rating)
print(price)
print(latitude)
print(longitude)
# Out:
# ['Molinari Delicatessen']
# ['373 Columbus Ave']
# ['San Francisco']
# ['CA']
# ['94133']
# ['+14154212337']
# ['Delis']
# [4.5]
# ['$$']
# [37.79838]
# [-122.40782]

# %%
# Drop rows with no phone number data
clean_df = new_df.dropna(subset=['phones'])

# %%
# Count after drop
len(clean_df)
# Out:
# 16441

# %%
# Reset the index and display the clean data frame
clean_df.reset_index()
clean_df
# Out:
#                                                    name  \
# 0                     Village Inn Restaurant and Bakery
# 1                                        Atlantic No. 5
# 2                                         Famous Dave's
# 3                                              The Feve
# 4                                               Quiznos
# 5                                           Hobbit Cafe
# 6                                         Familia Pizza
# 7                            Lalibela Ethiopian Cuisine
# 8                                  Villa Pizza (closed)
# 9                                          The Pita Pit
# 10                            P.f. Chang's China Bistro
# 11                                        Marco's Pizza
# 12                                               King I
# 13                                            Pizza Pit
# 14                                            Mcforters
# 15                             Sonny's Real Pit Bar-b-q
# ...

# %%
# Create standard formating for all phone numbers listed
clean_df['phones'] = clean_df['phones'].str.replace('["', '')
clean_df
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-44-f6e64c30b05b> in <module>()
#       1 # Create standard formating for all phone numbers listed
# ----> 2 clean_df['phones'] = clean_df['phones'].str.replace('["', '')
#       3 clean_df
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/strings.py in replace(self, pat, repl, n, case, flags)
#    1572     def replace(self, pat, repl, n=-1, case=None, flags=0):
#    1573         result = str_replace(self._data, pat, repl, n=n, case=case,
# -> 1574                              flags=flags)
#    1575         return self._wrap_result(result)
#    1576
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/strings.py in str_replace(arr, pat, repl, n, case, flags)
#     422     if use_re:
#     423         n = n if n >= 0 else 0
# --> 424         regex = re.compile(pat, flags=flags)
# ...

# %%
# Create yelp review, yelp price, and yelp category column

# %%
# Yelp API Setup
country_code = "+1"

# %%
# Access the Yelp API and grab the Yelp Review Value, Price Range, Category

# %%
# Sort list by State

# %%
# Export Clean CSV
