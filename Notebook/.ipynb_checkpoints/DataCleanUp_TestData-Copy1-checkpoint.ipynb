# %%
# Import Dependencies
import pandas as pd
import json
import requests
import numpy as np

# %%
# Path to the CSV
file = "../RawData/test_data.csv"

# Read the CSV into Pandas
df = pd.read_csv(file)
df.head
# Out:
# <bound method NDFrame.head of                   address                                         categories  \
# 0   2871 Gulf To Bay Blvd  American, American (new), Clearwater Restauran...
# 1           605 W Main St                             Caf and Sandwich Place
# 2         3803 9th St S W  American, Barbecue, Puyallup Restaurants, Barb...
# 3            30 S Main St  Coffee & Tea, Restaurant, Restaurants, Bar, Am...
# 4          55 Crescent Dr            Sandwich Place and Fast Food Restaurant
# 5       2243 Richmond Ave        English Restaurant, Caf, and Breakfast Spot
# 6        8007 State Rt 31                                 Pizza, Restaurants
# 7         415 Thompson Ln  Nashville Restaurants, Glencliff Estates, Rest...
# 8         217 W Beloit St  Orfordville Restaurants, Italian / Pizza / Veg...
# 9        309 N Lamar Blvd                                        Restaurants
# 10      1819 Lake Cook Rd  Mandarin, Restaurants, Northbrook Restaurants,...
# 11     6286 N College Ave  American, Pizza, Indianapolis Restaurants, War...
# 12         145 Charles St  Chinese Restaurants, Asian Restaurants, Take O...
# 13          113 Monroe St   Delta Restaurants, Pizza / American / Vegetarian
# 14          302 S 38th St          Omaha Restaurants, Blackstone, Vegetarian
# 15        7830 Highway 92  Woodstock Restaurants, Barbecue / Soul Food / ...
# 16           26 5th Ave N  ["Sandwich Place","Wraps","Sandwiches","Americ...
# 17   249 N Rocky River Dr  Pizza, Restaurant, Restaurants, Berea Restaura...
#
#              city          claimed country  \
# 0      Clearwater              NaN      US
# 1      Louisville              NaN      US
# 2        Puyallup              NaN      US
# 3         Oberlin              NaN      US
# 4   Pleasant Hill  yellowpages.com      US
# 5         Houston              NaN      US
# 6      Bridgeport              NaN      US
# 7       Nashville              NaN      US
# 8     Orfordville              NaN      US
# 9          Oxford              NaN      US
# 10     Northbrook              NaN      US
# 11   Indianapolis              NaN      US
# 12         Boston              NaN      US
# 13          Delta              NaN      US
# 14          Omaha              NaN      US
# 15      Woodstock              NaN      US
# 16     Waite Park              NaN      US
# 17          Berea              NaN      US
#
#                                              cuisines            dateOpened  \
# 0                                                 NaN                   NaN
# 1                          Vegetarian, Â Delicatessen                   NaN
# 2                                                 NaN                   NaN
# 3   Coffee & Tea, Restaurants, American, Â Bar, Â ...                   NaN
# 4   Take Out Restaurants, Asian Restaurants, Resta...                   NaN
# 5   Coffee Shops, American Restaurants, Restaurant...                   NaN
# 6   New York Style Pizza, Pizza By The Slice, Home...  2011-01-01T12:00:00Z
# 7                      African, Ethiopian, Vegetarian                   NaN
# 8                                                 NaN                   NaN
# 9                       American, Vegetarian, Healthy                   NaN
# 10                                           Mandarin  1993-01-01T12:00:00Z
# 11                                              Pizza                   NaN
# 12  Chinese Restaurants, Asian Restaurants, Take O...                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
# 16                                                NaN                   NaN
# 17                                Mexican, Vegetarian                   NaN
#
#              dateUpdated                                       descriptions  \
# 0   2014-02-01T04:41:06Z  Tags: American (New), American, and Trendy Sta...
# 1   2016-07-23T22:37:24Z  Atlantic No. 5, Louisville: See 4 unbiased rev...
# 2   2015-11-19T22:22:31Z  Description:  Famous Dave's is a Barbecue , Am...
# 3   2016-06-20T17:47:10Z  The Feve, Oberlin: See 170 unbiased reviews of...
# 4   2016-07-23T23:55:05Z  ["https://www.zagat.com/r/yalla-mediterranean-...
# 5   2016-07-23T23:24:12Z    ["https://www.zagat.com/r/hobbit-cafe-houston"]
# 6   2015-11-19T22:21:54Z  Check Out Our Full Menu At: www.myfamiliapizza...
# 7   2013-09-16T03:03:44Z                 Tags: nothing yet. tagging it. -->
# 8   2013-09-15T02:05:19Z  Tags: Italian, Pizza, and Family Style Stats: ...
# 9   2013-09-18T03:45:30Z                                                NaN
# 10  2014-01-10T18:14:14Z  Tags: Asian, Beer Served, and Delivery Stats: ...
# 11  2015-11-19T22:21:37Z  Tags: Pizza, Family Style, and Vegetarian Stat...
# 12  2016-07-22T15:31:40Z            King and I, Casual Dining Thai cuisine.
# 13  2013-09-23T02:53:22Z            Tags: Pizza, American, and Family Style
# 14  2013-09-12T04:51:27Z                      Tags: Vegetarian and Delivery
# 15  2013-09-16T04:07:44Z  Tags: Barbecue, Soul Food, and Family Style St...
# 16  2016-05-06T05:02:22Z  Tags: Sandwiches, Wraps, and Vegan Stats: 135 ...
# 17  2015-11-19T22:21:26Z                 Tags: nothing yet. tagging it. -->
#
#     facebookPageURL               ...                \
# 0               NaN               ...
# 1               NaN               ...
# 2               NaN               ...
# 3               NaN               ...
# 4               NaN               ...
# 5               NaN               ...
# 6               NaN               ...
# 7               NaN               ...
# 8               NaN               ...
# 9               NaN               ...
# 10              NaN               ...
# 11              NaN               ...
# 12              NaN               ...
# 13              NaN               ...
# 14              NaN               ...
# 15              NaN               ...
# 16              NaN               ...
# 17              NaN               ...
#
#                                               menuURL  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3               /oberlin-oh/mip/the-feve-8940755/menu
# 4   /pleasant-hill-ca/mip/yalla-mediterranean-5061...
# 5           /houston-tx/mip/hobbit-cafe-22358589/menu
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  http://www.yellowpages.com/boston-ma/mip/king-...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#                                     name  \
# 0      Village Inn Restaurant and Bakery
# 1                         Atlantic No. 5
# 2                          Famous Dave's
# 3                               The Feve
# 4                                Quiznos
# 5                            Hobbit Cafe
# 6                          Familia Pizza
# 7             Lalibela Ethiopian Cuisine
# 8                   Villa Pizza (closed)
# 9                           The Pita Pit
# 10             P.f. Chang's China Bistro
# 11                         Marco's Pizza
# 12                                King I
# 13                             Pizza Pit
# 14                             Mcforters
# 15              Sonny's Real Pit Bar-b-q
# 16                    Milio's Sandwiches
# 17  Oven Fresh Pizza - Southwest - Berea
#
#                                          paymentTypes  \
# 0                                                 NaN
# 1                                                 Yes
# 2                                                 NaN
# 3               mastercard, amex, discover, Yes, visa
# 4                                   master card, visa
# 5   check, discover, cash, amex, all major credit ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11       MasterCard, Visa, Discover, American Express
# 12  amex, discover, master card, visa, cash, diner...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#                                       phones  postalCode  \
# 0                                 7277964988       33759
# 1                                 5028833398       40202
# 2                                 2536040340       98373
# 3   ["4407741978","4197741978","4407753064"]       44074
# 4                                 9258258644       94523
# 5                             ["7135265460"]   ["77098"]
# 6                                 3156339909       13030
# 7                                 6153320710  37211-2212
# 8                                 6088799929       53576
# 9                                 6622383535  38655-3201
# 10                                  8.48E+09       60062
# 11                                3172144100       46220
# 12                                6172273320        2114
# 13                                4199236880       43515
# 14                                4023457477  68131-3806
# 15                                7709267848       30189
# 16                            ["3202031800"]   ["56387"]
# 17                                4402435656       44017
#
#                priceRange  province     sic     twitter  \
# 0                     NaN        FL  8423.0         NaN
# 1         USD 25.00-40.00        KY     NaN         NaN
# 2   USD 10.00 - USD 15.00        WA  5610.0         NaN
# 3         USD 25.00-40.00        OH     NaN         NaN
# 4                       $        CA     NaN     quiznos
# 5         USD 25.00-40.00        TX     NaN  cafehobbit
# 6                     NaN        NY  5610.0         NaN
# 7          USD 5 - USD 10        TN  5610.0         NaN
# 8                     NaN        WI  5610.0         NaN
# 9                     NaN        MS  5610.0         NaN
# 10                    NaN        IL     NaN         NaN
# 11  USD 10.00 - USD 15.00        IN  5610.0         NaN
# 12                     $$        MA     NaN         NaN
# 13                    NaN        OH  5610.0         NaN
# 14                    NaN        NE  5610.0         NaN
# 15                    NaN        GA  5610.0         NaN
# 16                      $        MN  5610.0         NaN
# 17   USD 0.00 - USD 25.00        OH  5610.0         NaN
#
#                           websites
# 0                              NaN
# 1                  atlanticno5.com
# 2           http://famousdaves.com
# 3           http://www.thefeve.com
# 4        http://www.yallamedi.com/
# 5     http://www.myhobbitcafe.com/
# 6    http://www.myfamiliapizza.com
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10         http://www.pfchangs.com
# 11                             NaN
# 12  http://www.kingandi-boston.com
# 13             http://pizzapit.com
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
#
# [18 rows x 29 columns]>

# %%
df.columns
# Out:
# Index(['address', 'categories', 'city', 'claimed', 'country', 'cuisines',
#        'dateOpened', 'dateUpdated', 'descriptions', 'facebookPageURL',
#        'features', 'hours', 'images', 'isClosed', 'key', 'lat', 'languages',
#        'long', 'menus', 'menuURL', 'name', 'paymentTypes', 'phones',
#        'postalCode', 'priceRange', 'province', 'sic', 'twitter', 'websites'],
#       dtype='object')

# %%
new_df = df.loc[:, ["name", "address", "city", "province", "postalCode", "phones", "cuisines", "descriptions", "features", "lat", "long"]]
new_df
# Out:
#                                     name                address  \
# 0      Village Inn Restaurant and Bakery  2871 Gulf To Bay Blvd
# 1                         Atlantic No. 5          605 W Main St
# 2                          Famous Dave's        3803 9th St S W
# 3                               The Feve           30 S Main St
# 4                                Quiznos         55 Crescent Dr
# 5                            Hobbit Cafe      2243 Richmond Ave
# 6                          Familia Pizza       8007 State Rt 31
# 7             Lalibela Ethiopian Cuisine        415 Thompson Ln
# 8                   Villa Pizza (closed)        217 W Beloit St
# 9                           The Pita Pit       309 N Lamar Blvd
# 10             P.f. Chang's China Bistro      1819 Lake Cook Rd
# 11                         Marco's Pizza     6286 N College Ave
# 12                                King I         145 Charles St
# 13                             Pizza Pit          113 Monroe St
# 14                             Mcforters          302 S 38th St
# 15              Sonny's Real Pit Bar-b-q        7830 Highway 92
# 16                    Milio's Sandwiches           26 5th Ave N
# 17  Oven Fresh Pizza - Southwest - Berea   249 N Rocky River Dr
#
#              city province  postalCode  \
# 0      Clearwater       FL       33759
# 1      Louisville       KY       40202
# 2        Puyallup       WA       98373
# 3         Oberlin       OH       44074
# 4   Pleasant Hill       CA       94523
# 5         Houston       TX   ["77098"]
# 6      Bridgeport       NY       13030
# 7       Nashville       TN  37211-2212
# 8     Orfordville       WI       53576
# 9          Oxford       MS  38655-3201
# 10     Northbrook       IL       60062
# 11   Indianapolis       IN       46220
# 12         Boston       MA        2114
# 13          Delta       OH       43515
# 14          Omaha       NE  68131-3806
# 15      Woodstock       GA       30189
# 16     Waite Park       MN   ["56387"]
# 17          Berea       OH       44017
#
#                                       phones  \
# 0                                 7277964988
# 1                                 5028833398
# 2                                 2536040340
# 3   ["4407741978","4197741978","4407753064"]
# 4                                 9258258644
# 5                             ["7135265460"]
# 6                                 3156339909
# 7                                 6153320710
# 8                                 6088799929
# 9                                 6622383535
# 10                                  8.48E+09
# 11                                3172144100
# 12                                6172273320
# 13                                4199236880
# 14                                4023457477
# 15                                7709267848
# 16                            ["3202031800"]
# 17                                4402435656
#
#                                              cuisines  \
# 0                                                 NaN
# 1                          Vegetarian, Â Delicatessen
# 2                                                 NaN
# 3   Coffee & Tea, Restaurants, American, Â Bar, Â ...
# 4   Take Out Restaurants, Asian Restaurants, Resta...
# 5   Coffee Shops, American Restaurants, Restaurant...
# 6   New York Style Pizza, Pizza By The Slice, Home...
# 7                      African, Ethiopian, Vegetarian
# 8                                                 NaN
# 9                       American, Vegetarian, Healthy
# 10                                           Mandarin
# 11                                              Pizza
# 12  Chinese Restaurants, Asian Restaurants, Take O...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                Mexican, Vegetarian
#
#                                          descriptions  \
# 0   Tags: American (New), American, and Trendy Sta...
# 1   Atlantic No. 5, Louisville: See 4 unbiased rev...
# 2   Description:  Famous Dave's is a Barbecue , Am...
# 3   The Feve, Oberlin: See 170 unbiased reviews of...
# 4   ["https://www.zagat.com/r/yalla-mediterranean-...
# 5     ["https://www.zagat.com/r/hobbit-cafe-houston"]
# 6   Check Out Our Full Menu At: www.myfamiliapizza...
# 7                  Tags: nothing yet. tagging it. -->
# 8   Tags: Italian, Pizza, and Family Style Stats: ...
# 9                                                 NaN
# 10  Tags: Asian, Beer Served, and Delivery Stats: ...
# 11  Tags: Pizza, Family Style, and Vegetarian Stat...
# 12            King and I, Casual Dining Thai cuisine.
# 13            Tags: Pizza, American, and Family Style
# 14                      Tags: Vegetarian and Delivery
# 15  Tags: Barbecue, Soul Food, and Family Style St...
# 16  Tags: Sandwiches, Wraps, and Vegan Stats: 135 ...
# 17                 Tags: nothing yet. tagging it. -->
#
#                                              features        lat        long
# 0                                                 NaN  27.971165  -82.696938
# 1   [{"key":"Value Rating","value":"3.5 of 5 stars...  38.257020  -85.760013
# 2                                                 NaN  47.154828 -122.303992
# 3   [{"key":"AKA:","value":"Feve The"},{"key":"Val...  41.290823  -82.217640
# 4    [{"key":"Price Range ","value":"Below Average"}]  37.945663 -122.061997
# 5   [{"key":"Other Information","value":"Parking: ...  29.733600  -95.414600
# 6                                                 NaN        NaN         NaN
# 7                                                 NaN  36.119880  -86.718505
# 8                                                 NaN  42.635024  -89.268167
# 9                                                 NaN  34.368020  -89.518390
# 10                                                NaN  42.151959  -87.821541
# 11                                                NaN  39.869489  -86.146425
# 12  [{"key":"Take Out","value":"Yes"},{"key":"Good...  42.360313  -71.070810
# 13                                                NaN  41.574067  -84.007303
# 14                                                NaN  41.257512  -95.969320
# 15                                                NaN        NaN         NaN
# 16                                                NaN  45.553367  -94.222893
# 17                                                NaN  41.372713  -81.861268

# %%
clean_df = new_df.dropna(subset=['lat'])
clean_df
# Out:
#                                     name                address  \
# 0      Village Inn Restaurant and Bakery  2871 Gulf To Bay Blvd
# 1                         Atlantic No. 5          605 W Main St
# 2                          Famous Dave's        3803 9th St S W
# 3                               The Feve           30 S Main St
# 4                                Quiznos         55 Crescent Dr
# 5                            Hobbit Cafe      2243 Richmond Ave
# 7             Lalibela Ethiopian Cuisine        415 Thompson Ln
# 8                   Villa Pizza (closed)        217 W Beloit St
# 9                           The Pita Pit       309 N Lamar Blvd
# 10             P.f. Chang's China Bistro      1819 Lake Cook Rd
# 11                         Marco's Pizza     6286 N College Ave
# 12                                King I         145 Charles St
# 13                             Pizza Pit          113 Monroe St
# 14                             Mcforters          302 S 38th St
# 16                    Milio's Sandwiches           26 5th Ave N
# 17  Oven Fresh Pizza - Southwest - Berea   249 N Rocky River Dr
#
#              city province  postalCode  \
# 0      Clearwater       FL       33759
# 1      Louisville       KY       40202
# 2        Puyallup       WA       98373
# 3         Oberlin       OH       44074
# 4   Pleasant Hill       CA       94523
# 5         Houston       TX   ["77098"]
# 7       Nashville       TN  37211-2212
# 8     Orfordville       WI       53576
# 9          Oxford       MS  38655-3201
# 10     Northbrook       IL       60062
# 11   Indianapolis       IN       46220
# 12         Boston       MA        2114
# 13          Delta       OH       43515
# 14          Omaha       NE  68131-3806
# 16     Waite Park       MN   ["56387"]
# 17          Berea       OH       44017
#
#                                       phones  \
# 0                                 7277964988
# 1                                 5028833398
# 2                                 2536040340
# 3   ["4407741978","4197741978","4407753064"]
# 4                                 9258258644
# 5                             ["7135265460"]
# 7                                 6153320710
# 8                                 6088799929
# 9                                 6622383535
# 10                                  8.48E+09
# 11                                3172144100
# 12                                6172273320
# 13                                4199236880
# 14                                4023457477
# 16                            ["3202031800"]
# 17                                4402435656
#
#                                              cuisines  \
# 0                                                 NaN
# 1                          Vegetarian, Â Delicatessen
# 2                                                 NaN
# 3   Coffee & Tea, Restaurants, American, Â Bar, Â ...
# 4   Take Out Restaurants, Asian Restaurants, Resta...
# 5   Coffee Shops, American Restaurants, Restaurant...
# 7                      African, Ethiopian, Vegetarian
# 8                                                 NaN
# 9                       American, Vegetarian, Healthy
# 10                                           Mandarin
# 11                                              Pizza
# 12  Chinese Restaurants, Asian Restaurants, Take O...
# 13                                                NaN
# 14                                                NaN
# 16                                                NaN
# 17                                Mexican, Vegetarian
#
#                                          descriptions  \
# 0   Tags: American (New), American, and Trendy Sta...
# 1   Atlantic No. 5, Louisville: See 4 unbiased rev...
# 2   Description:  Famous Dave's is a Barbecue , Am...
# 3   The Feve, Oberlin: See 170 unbiased reviews of...
# 4   ["https://www.zagat.com/r/yalla-mediterranean-...
# 5     ["https://www.zagat.com/r/hobbit-cafe-houston"]
# 7                  Tags: nothing yet. tagging it. -->
# 8   Tags: Italian, Pizza, and Family Style Stats: ...
# 9                                                 NaN
# 10  Tags: Asian, Beer Served, and Delivery Stats: ...
# 11  Tags: Pizza, Family Style, and Vegetarian Stat...
# 12            King and I, Casual Dining Thai cuisine.
# 13            Tags: Pizza, American, and Family Style
# 14                      Tags: Vegetarian and Delivery
# 16  Tags: Sandwiches, Wraps, and Vegan Stats: 135 ...
# 17                 Tags: nothing yet. tagging it. -->
#
#                                              features        lat        long
# 0                                                 NaN  27.971165  -82.696938
# 1   [{"key":"Value Rating","value":"3.5 of 5 stars...  38.257020  -85.760013
# 2                                                 NaN  47.154828 -122.303992
# 3   [{"key":"AKA:","value":"Feve The"},{"key":"Val...  41.290823  -82.217640
# 4    [{"key":"Price Range ","value":"Below Average"}]  37.945663 -122.061997
# 5   [{"key":"Other Information","value":"Parking: ...  29.733600  -95.414600
# 7                                                 NaN  36.119880  -86.718505
# 8                                                 NaN  42.635024  -89.268167
# 9                                                 NaN  34.368020  -89.518390
# 10                                                NaN  42.151959  -87.821541
# 11                                                NaN  39.869489  -86.146425
# 12  [{"key":"Take Out","value":"Yes"},{"key":"Good...  42.360313  -71.070810
# 13                                                NaN  41.574067  -84.007303
# 14                                                NaN  41.257512  -95.969320
# 16                                                NaN  45.553367  -94.222893
# 17                                                NaN  41.372713  -81.861268

# %%
# Count before drop
len(new_df)
# Out:
# 18

# %%
# Count after drop
len(clean_df)
# Out:
# 16

# %%
# Create lists for Yelp API Data
name = []
restaurant_name = []
lat = []
long = []
address = []
city = []
state = []
zip_code = []
phone = []
cuisine_type = []
rating = []
price = []
latitude = []
longitude = []

clean_df.head()
# Out:
#                                 name                address           city  \
# 0  Village Inn Restaurant and Bakery  2871 Gulf To Bay Blvd     Clearwater
# 1                     Atlantic No. 5          605 W Main St     Louisville
# 2                      Famous Dave's        3803 9th St S W       Puyallup
# 3                           The Feve           30 S Main St        Oberlin
# 4                            Quiznos         55 Crescent Dr  Pleasant Hill
#
#   province postalCode                                    phones  \
# 0       FL      33759                                7277964988
# 1       KY      40202                                5028833398
# 2       WA      98373                                2536040340
# 3       OH      44074  ["4407741978","4197741978","4407753064"]
# 4       CA      94523                                9258258644
#
#                                             cuisines  \
# 0                                                NaN
# 1                         Vegetarian, Â Delicatessen
# 2                                                NaN
# 3  Coffee & Tea, Restaurants, American, Â Bar, Â ...
# 4  Take Out Restaurants, Asian Restaurants, Resta...
#
#                                         descriptions  \
# 0  Tags: American (New), American, and Trendy Sta...
# 1  Atlantic No. 5, Louisville: See 4 unbiased rev...
# 2  Description:  Famous Dave's is a Barbecue , Am...
# 3  The Feve, Oberlin: See 170 unbiased reviews of...
# 4  ["https://www.zagat.com/r/yalla-mediterranean-...
#
#                                             features        lat        long
# 0                                                NaN  27.971165  -82.696938
# 1  [{"key":"Value Rating","value":"3.5 of 5 stars...  38.257020  -85.760013
# 2                                                NaN  47.154828 -122.303992
# 3  [{"key":"AKA:","value":"Feve The"},{"key":"Val...  41.290823  -82.217640
# 4   [{"key":"Price Range ","value":"Below Average"}]  37.945663 -122.061997

# %%
url = "https://api.yelp.com/v3/businesses/search"



headers = {
    'authorization': "Bearer Vq7NhNf0npR8Ki7ka12hfLgHiw-GQ7e2dI0AziNivXvglpD3YH4FAfkgNRlz8sX5bLJJXIZXWRt2j0hoBEzWCWbl6Fnl_aNmRtqEr81xjkoeZjpzrbAXqEYC3z-tWnYx",
    'cache-control': "no-cache",
    'postman-token': "965c5340-e9c7-c7ca-3c68-0dfb83acf159"
    }

record_count = 1
group_number = 1

for x in range(0, len(clean_df)):
    term = clean_df.iloc[x]['name']
    latitude = clean_df.iloc[x]['lat']
    longitude = clean_df.iloc[x]['long']
    querystring = {"term":term,"latitude":latitude,"longitude":longitude,"limit":"1"}
    print(querystring)
    response = requests.request("GET", url, headers=headers, params=querystring)
    data = response.json()
    print(data)
    # Store response as variables
    r1 = data['businesses'][0]['name']
    r2 = data['businesses'][0]['location']['address1']
    r3 = data['businesses'][0]['location']['city']
    r4 = data['businesses'][0]['location']['state']
    r5 = data['businesses'][0]['location']['zip_code']
    r6 = data['businesses'][0]['phone']
    r7 = data['businesses'][0]['categories'][0]['title']
    r8 = data['businesses'][0]['rating']
    r9 = data['businesses'][0]['price']
    r10 = data['businesses'][0]['coordinates']['latitude']
    r11 = data['businesses'][0]['coordinates']['longitude']
    print(str(r1))
    print(str(r2))
    print(str(r3))
    print(str(r4))
    print(str(r5))
    print(str(r6))
    print(str(r7))
    print(str(r8))
    print(str(r9))
    print(str(r10))
    print(str(r11))
    # Append to lists
    restaurant_name.append(r1)
    address.append(r2)
    city.append(r3)
    state.append(r4)
    zip_code.append(r5)
    phone.append(r6)
    cuisine_type.append(r7)
    rating.append(r8)
    price.append(r9)
    latitude = np.append(r10, latitude)
    longitude = np.append(r11, longitude)    
    # Pause every 50 API Calls
    if record_count < 50:
        record_count = record_count + 1
    elif record_count == 50:
        time.sleep(15)
        record_count = 1
        group_number = group_number + 1
# Out:
# {'term': 'Village Inn Restaurant and Bakery', 'latitude': 27.971165000000003, 'longitude': -82.696938000000003, 'limit': '1'}
# {'businesses': [{'id': 'fridas-cafe-and-bakery-largo', 'name': "Frida's Cafe & Bakery", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A8s-ZstSmN8we3gdgWdFlA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/fridas-cafe-and-bakery-largo?adjust_creative=VvaqZOQWhwGm3PuibGw_Zg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VvaqZOQWhwGm3PuibGw_Zg', 'review_count': 223, 'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'desserts', 'title': 'Desserts'}], 'rating': 4.0, 'coordinates': {'latitude': 27.89441, 'longitude': -82.773583}, 'transactions': ['pickup'], 'price': '$', 'location': {'address1': '9700 Ulmerton Rd', 'address2': None, 'address3': '', 'city': 'Largo', 'zip_code': '33771', 'country': 'US', 'state': 'FL', 'display_address': ['9700 Ulmerton Rd', 'Largo, FL 33771']}, 'phone': '+17275877077', 'display_phone': '(727) 587-7077', 'distance': 11381.45066539298}], 'total': 1, 'region': {'center': {'longitude': -82.696938, 'latitude': 27.971165}}}
# Frida's Cafe & Bakery
# 9700 Ulmerton Rd
# Largo
# FL
# 33771
# +17275877077
# Bakeries
# 4.0
# $
# 27.89441
# -82.773583
# {'term': 'Atlantic No. 5', 'latitude': 38.257020349999998, 'longitude': -85.760013279999995, 'limit': '1'}
# {'businesses': [{'id': 'atlantic-no-5-louisville', 'name': 'Atlantic No 5', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xmPWh73qDsKu3hOBoCfeDg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/atlantic-no-5-louisville?adjust_creative=VvaqZOQWhwGm3PuibGw_Zg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VvaqZOQWhwGm3PuibGw_Zg', 'review_count': 92, 'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cafes', 'title': 'Cafes'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}], 'rating': 4.0, 'coordinates': {'latitude': 38.257374, 'longitude': -85.760051}, 'transactions': [], 'price': '$$', 'location': {'address1': '605 W Main St', 'address2': '', 'address3': '', 'city': 'Louisville', 'zip_code': '40202', 'country': 'US', 'state': 'KY', 'display_address': ['605 W Main St', 'Louisville, KY 40202']}, 'phone': '+15028833398', 'display_phone': '(502) 883-3398', 'distance': 39.461721369052}], 'total': 8, 'region': {'center': {'longitude': -85.76001328, 'latitude': 38.25702035}}}
# Atlantic No 5
# 605 W Main St
# Louisville
# KY
# 40202
# +15028833398
# Breakfast & Brunch
# 4.0
# $$
# 38.257374
# -85.760051
# {'term': "Famous Dave's", 'latitude': 47.154828000000002, 'longitude': -122.30399199999999, 'limit': '1'}
# {'businesses': [{'id': 'famous-daves-puyallup', 'name': 'Famous Daves', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kTB57rFhdtIPctN_j-TP1A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/famous-daves-puyallup?adjust_creative=VvaqZOQWhwGm3PuibGw_Zg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VvaqZOQWhwGm3PuibGw_Zg', 'review_count': 103, 'categories': [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'catering', 'title': 'Caterers'}], 'rating': 3.0, 'coordinates': {'latitude': 47.15593, 'longitude': -122.30322}, 'transactions': [], 'price': '$$', 'location': {'address1': '3811 9th St SW', 'address2': None, 'address3': '', 'city': 'Puyallup', 'zip_code': '98373', 'country': 'US', 'state': 'WA', 'display_address': ['3811 9th St SW', 'Puyallup, WA 98373']}, 'phone': '+12536040340', 'display_phone': '(253) 604-0340', 'distance': 135.730425114438}], 'total': 200, 'region': {'center': {'longitude': -122.303992, 'latitude': 47.154828}}}
# Famous Daves
# 3811 9th St SW
# Puyallup
# WA
# 98373
# +12536040340
# Barbeque
# 3.0
# $$
# 47.15593
# -122.30322
# {'term': 'The Feve', 'latitude': 41.290822769999998, 'longitude': -82.217640279999998, 'limit': '1'}
# {'businesses': [{'id': 'the-feve-oberlin', 'name': 'The Feve', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JXnjf4yedR5e1hx0lbVUCA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-feve-oberlin?adjust_creative=VvaqZOQWhwGm3PuibGw_Zg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VvaqZOQWhwGm3PuibGw_Zg', 'review_count': 161, 'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'delis', 'title': 'Delis'}, {'alias': 'lounges', 'title': 'Lounges'}], 'rating': 4.5, 'coordinates': {'latitude': 41.290828704834, 'longitude': -82.2177276611328}, 'transactions': [], 'price': '$$', 'location': {'address1': '30 S Main St', 'address2': '', 'address3': '', 'city': 'Oberlin', 'zip_code': '44074', 'country': 'US', 'state': 'OH', 'display_address': ['30 S Main St', 'Oberlin, OH 44074']}, 'phone': '+14407741978', 'display_phone': '(440) 774-1978', 'distance': 6.668861788726}], 'total': 6, 'region': {'center': {'longitude': -82.21764028, 'latitude': 41.29082277}}}
# The Feve
# 30 S Main St
# Oberlin
# OH
# 44074
# +14407741978
# Coffee & Tea
# 4.5
# $$
# 41.290828704834
# -82.2177276611328
# {'term': 'Quiznos', 'latitude': 37.94566339, 'longitude': -122.06199690000001, 'limit': '1'}
# {'businesses': [{'id': 'quiznos-walnut-creek-11', 'name': 'Quiznos', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/01pS2REkGMWbUENwubtzDA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/quiznos-walnut-creek-11?adjust_creative=VvaqZOQWhwGm3PuibGw_Zg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VvaqZOQWhwGm3PuibGw_Zg', 'review_count': 21, 'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'hotdogs', 'title': 'Fast Food'}], 'rating': 3.5, 'coordinates': {'latitude': 37.9298004, 'longitude': -122.0166192}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '2236A Oak Grove Rd', 'address2': '', 'address3': '', 'city': 'Walnut Creek', 'zip_code': '94598', 'country': 'US', 'state': 'CA', 'display_address': ['2236A Oak Grove Rd', 'Walnut Creek, CA 94598']}, 'phone': '+19259441231', 'display_phone': '(925) 944-1231', 'distance': 4417.508793674322}], 'total': 212, 'region': {'center': {'longitude': -122.0619969, 'latitude': 37.94566339}}}
# Quiznos
# 2236A Oak Grove Rd
# Walnut Creek
# CA
# 94598
# +19259441231
# Sandwiches
# 3.5
# $
# 37.9298004
# -122.0166192
# {'term': 'Hobbit Cafe', 'latitude': 29.733599999999999, 'longitude': -95.414599999999993, 'limit': '1'}
# {'businesses': [{'id': 'hobbit-cafe-houston', 'name': 'Hobbit Cafe', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r7VPGYl2-IdPbFmgpRbr_Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hobbit-cafe-houston?adjust_creative=VvaqZOQWhwGm3PuibGw_Zg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VvaqZOQWhwGm3PuibGw_Zg', 'review_count': 797, 'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'gastropubs', 'title': 'Gastropubs'}, {'alias': 'vegetarian', 'title': 'Vegetarian'}], 'rating': 3.5, 'coordinates': {'latitude': 29.7340113, 'longitude': -95.4140505}, 'transactions': [], 'price': '$$', 'location': {'address1': '2243 Richmond Ave', 'address2': '', 'address3': '', 'city': 'Houston', 'zip_code': '77098', 'country': 'US', 'state': 'TX', 'display_address': ['2243 Richmond Ave', 'Houston, TX 77098']}, 'phone': '+17135265460', 'display_phone': '(713) 526-5460', 'distance': 37.16159003772599}], 'total': 19, 'region': {'center': {'longitude': -95.4146, 'latitude': 29.7336}}}
# Hobbit Cafe
# 2243 Richmond Ave
# Houston
# TX
# 77098
# +17135265460
# Breakfast & Brunch
# 3.5
# $$
# 29.7340113
# -95.4140505
# {'term': 'Lalibela Ethiopian Cuisine', 'latitude': 36.119880000000002, 'longitude': -86.718505000000007, 'limit': '1'}
# {'businesses': [], 'total': 0, 'region': {'center': {'longitude': -86.718505, 'latitude': 36.11988}}}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-727ba6d67c37> in <module>()
#      22     print(data)
#      23     # Store response as variables
# ---> 24     r1 = data['businesses'][0]['name']
#      25     r2 = data['businesses'][0]['location']['address1']
#      26     r3 = data['businesses'][0]['location']['city']
#
# IndexError: list index out of range

# %%
restaurant_name

# %%
# Yelp API Setup
country_code = "+1"

# %%
# Access the Yelp API and grab the Yelp Review Value, Price Range, Category

# %%
# Sort list by State

# %%
# Export Clean CSV
